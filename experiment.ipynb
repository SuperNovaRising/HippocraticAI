# %% [markdown]
# # Prompt engineering
# ## Prompts of original hip_agent implementation
# Running the test_bench twice, the test_bench gives different scores. Below, I highlighted the difference between the 2 rounds. I found the differences are caused by one of the run returns -1.
#
# Besides, I also printed out the prompt for later analysis.
#
# score = 6
# [[0, 3, 1], [0, -1, 1], [1, 3, 3], [1, 1, 1], [1, 0, 0], `[0, -1, 0]`, [0, -1, 3], [0, -1, 3], [0, -1, 1], `[0, -1, 1]`, [0, 0, 3], [0, -1, 0], `[0, -1, 1]`, [1, 2, 2], `[1, 3, 3]`, [0, -1, 2], [0, -1, 2], [0, -1, 3], [1, 2, 2], [0, -1, 0]]
#
# score = 8
# [[0, 3, 1], [0, -1, 1], [1, 3, 3], [1, 1, 1], [1, 0, 0], `[1, 0, 0]`, [0, -1, 3], [0, -1, 3], [0, -1, 1], `[1, 1, 1]`, [0, 0, 3], [0, -1, 0], `[1, 1, 1]`, [1, 2, 2], `[0, -1, 3]`, [0, -1, 2], [0, -1, 2], [0, -1, 3], [1, 2, 2], [0, -1, 0]]

# %%
"""
GMOs are created by ________ 

generating genomic DNA fragments with restriction endonucleases
introducing recombinant DNA into an organism by any means
overexpressing proteins in E. coli
all of the above


Insulin produced by molecular cloning: 

is of pig origin
is a recombinant protein
is made by the human pancreas
is recombinant DNA


The Flavr Savr Tomato: 

is a variety of vine-ripened tomato in the supermarket
was created to have better flavor and shelf-life
does not undergo soft rot
all of the above


Linkage analysis ________ 

is used to create a physical map
is based on the natural recombination process
requires radiation hybrid mapping
involves breaking and rejoining of DNA artificially


Individual genetic maps in a given species are: 

genetically similar
genetically identical
genetically dissimilar
not useful in species analysis


The chain termination method of sequencing: 

uses labeled ddNTPs
uses only dideoxynucleotides
uses only deoxynucleotides
uses labeled dNTPs


Sequencing an individual person’s genome 

is currently possible
could lead to legal issues regarding discrimination and privacy
could help make informed choices about medical treatment
all of the above


Genomics can be used in agriculture to: 

generate new hybrid strains
improve disease resistance
improve yield
all of the above


What is a biomarker? 

the color coding of different genes
a protein that is uniquely produced in a diseased state
a molecule in the genome or proteome
a marker that is genetically inherited


Which scientific concept did Charles Darwin and Alfred Wallace independently discover? 

mutation
natural selection
overbreeding
sexual reproduction


Which description is an example of a phenotype? 

A certain duck has a blue beak
A mutation occurred to a flower
Most cheetahs live solitary lives
both a and c


Which situation would most likely lead to allopatric speciation? 

Flood causes the formation of a new lake
A storm causes several large trees to fall down
A mutation causes a new trait to develop
An injury


Which variable increases the likelihood of allopatric speciation taking place more quickly? 

lower rate of mutation
longer distance between divided groups
increased instances of hybrid formation
equivalent numbers of individuals in each population


Which reproductive combination produces hybrids? 

when individuals of the same species in different geographical areas reproduce
when any two individuals sharing the same habitat reproduce
when members of closely related species reproduce
when offspring of the same parents reproduce


Which situation is not an example of a prezygotic barrier? 

Two species of turtles breed at different times of the year
Two species of flowers attract different pollinators
Two species of birds display different mating dances
Two species of insects produce infertile offspring


Which components of speciation would be least likely to be a part of punctuated equilibrium? 

a division of populations
a change in environmental conditions
ongoing gene flow among all individuals
a large number of mutations taking place at once


What is the difference between micro- and macroevolution? 

Microevolution describes the evolution of small organisms, such as insects, while macroevolution describes the evolution of large organisms, like people and elephants.
Microevolution describes the evolution of microscopic entities, such as molecules and proteins, while macroevolution describes the evolution of whole organisms.
Microevolution describes the evolution of organisms in populations, while macroevolution describes the evolution of species over long periods of time.
Microevolution describes the evolution of organisms over their lifetimes, while macroevolution describes the evolution of organisms over multiple generations.


Which of the following populations is not in Hardy-Weinberg equilibrium? 

a population with 12 homozygous recessive individuals (yy), 8 homozygous dominant individuals (YY), and 4 heterozygous individuals (Yy)
a population in which the allele frequencies do not change over time
p2 + 2pq + q2 = 1
a population undergoing natural selection


When male lions reach sexual maturity, they leave their group in search of a new pride. This can alter the allele frequencies of the population through which of the following mechanisms? 

natural selection
genetic drift
gene flow
random mating


What is assortative mating? 

when individuals mate with those who are similar to themselves
when individuals mate with those who are dissimilar to themselves
when individuals mate with those who are the most fit in the population
when individuals mate with those who are least fit in the population
Score:6/20


[[0, 3, 1], [0, -1, 1], [1, 3, 3], [1, 1, 1], [1, 0, 0], [0, -1, 0], [0, -1, 3], [0, -1, 3], [0, -1, 1], [0, -1, 1], [0, 0, 3], [0, -1, 0], [0, -1, 1], [1, 2, 2], [1, 3, 3], [0, -1, 2], [0, -1, 2], [0, -1, 3], [1, 2, 2], [0, -1, 0]]

"""

# %%
"""
GMOs are created by ________ 

generating genomic DNA fragments with restriction endonucleases
introducing recombinant DNA into an organism by any means
overexpressing proteins in E. coli
all of the above



Insulin produced by molecular cloning: 

is of pig origin
is a recombinant protein
is made by the human pancreas
is recombinant DNA



The Flavr Savr Tomato: 

is a variety of vine-ripened tomato in the supermarket
was created to have better flavor and shelf-life
does not undergo soft rot
all of the above



Linkage analysis ________ 

is used to create a physical map
is based on the natural recombination process
requires radiation hybrid mapping
involves breaking and rejoining of DNA artificially



Individual genetic maps in a given species are: 

genetically similar
genetically identical
genetically dissimilar
not useful in species analysis



The chain termination method of sequencing: 

uses labeled ddNTPs
uses only dideoxynucleotides
uses only deoxynucleotides
uses labeled dNTPs



Sequencing an individual person’s genome 

is currently possible
could lead to legal issues regarding discrimination and privacy
could help make informed choices about medical treatment
all of the above



Genomics can be used in agriculture to: 

generate new hybrid strains
improve disease resistance
improve yield
all of the above



What is a biomarker? 

the color coding of different genes
a protein that is uniquely produced in a diseased state
a molecule in the genome or proteome
a marker that is genetically inherited



Which scientific concept did Charles Darwin and Alfred Wallace independently discover? 

mutation
natural selection
overbreeding
sexual reproduction



Which description is an example of a phenotype? 

A certain duck has a blue beak
A mutation occurred to a flower
Most cheetahs live solitary lives
both a and c



Which situation would most likely lead to allopatric speciation? 

Flood causes the formation of a new lake
A storm causes several large trees to fall down
A mutation causes a new trait to develop
An injury



Which variable increases the likelihood of allopatric speciation taking place more quickly? 

lower rate of mutation
longer distance between divided groups
increased instances of hybrid formation
equivalent numbers of individuals in each population



Which reproductive combination produces hybrids? 

when individuals of the same species in different geographical areas reproduce
when any two individuals sharing the same habitat reproduce
when members of closely related species reproduce
when offspring of the same parents reproduce



Which situation is not an example of a prezygotic barrier? 

Two species of turtles breed at different times of the year
Two species of flowers attract different pollinators
Two species of birds display different mating dances
Two species of insects produce infertile offspring



Which components of speciation would be least likely to be a part of punctuated equilibrium? 

a division of populations
a change in environmental conditions
ongoing gene flow among all individuals
a large number of mutations taking place at once



What is the difference between micro- and macroevolution? 

Microevolution describes the evolution of small organisms, such as insects, while macroevolution describes the evolution of large organisms, like people and elephants.
Microevolution describes the evolution of microscopic entities, such as molecules and proteins, while macroevolution describes the evolution of whole organisms.
Microevolution describes the evolution of organisms in populations, while macroevolution describes the evolution of species over long periods of time.
Microevolution describes the evolution of organisms over their lifetimes, while macroevolution describes the evolution of organisms over multiple generations.



Which of the following populations is not in Hardy-Weinberg equilibrium? 

a population with 12 homozygous recessive individuals (yy), 8 homozygous dominant individuals (YY), and 4 heterozygous individuals (Yy)
a population in which the allele frequencies do not change over time
p2 + 2pq + q2 = 1
a population undergoing natural selection



When male lions reach sexual maturity, they leave their group in search of a new pride. This can alter the allele frequencies of the population through which of the following mechanisms? 

natural selection
genetic drift
gene flow
random mating



What is assortative mating? 

when individuals mate with those who are similar to themselves
when individuals mate with those who are dissimilar to themselves
when individuals mate with those who are the most fit in the population
when individuals mate with those who are least fit in the population



Score:8/20


[[0, 3, 1], [0, -1, 1], [1, 3, 3], [1, 1, 1], [1, 0, 0], [1, 0, 0], [0, -1, 3], [0, -1, 3], [0, -1, 1], [1, 1, 1], [0, 0, 3], [0, -1, 0], [1, 1, 1], [1, 2, 2], [0, -1, 3], [0, -1, 2], [0, -1, 2], [0, -1, 3], [1, 2, 2], [0, -1, 0]]
"""

# %%
"""
[[0, 3, 1], [0, -1, 1], [1, 3, 3], [1, 1, 1], [1, 0, 0], [0, -1, 0], [0, -1, 3], [0, -1, 3], [0, -1, 1], [0, -1, 1], [0, 0, 3], [0, -1, 0], [0, -1, 1], [1, 2, 2], [1, 3, 3], [0, -1, 2], [0, -1, 2], [0, -1, 3], [1, 2, 2], [0, -1, 0]]
[[0, 3, 1], [0, -1, 1], [1, 3, 3], [1, 1, 1], [1, 0, 0], [1, 0, 0], [0, -1, 3], [0, -1, 3], [0, -1, 1], [1, 1, 1], [0, 0, 3], [0, -1, 0], [1, 1, 1], [1, 2, 2], [0, -1, 3], [0, -1, 2], [0, -1, 2], [0, -1, 3], [1, 2, 2], [0, -1, 0]]

"""

# %% [markdown]
# ## Investigate what causes `get_response` to return -1
# I printed out `response_text` which causes `get_response` to return -1
#
# Here is an example of the prompts and `response_text` for -1 cases:
# ```
# What is assortative mating?
#
# when individuals mate with those who are similar to themselves
# when individuals mate with those who are dissimilar to themselves
# when individuals mate with those who are the most fit in the population
# when individuals mate with those who are least fit in the population
#
#
# Assortative mating is when individuals mate with those who are similar to themselves. This can occur based on a variety of factors such as physical appearance, behavior, intelligence, or socioeconomic status.
# ```
# In fact, the gpt model gives the correct answer: "similar", but the answer is not exactly the same as the correct option.

# %%
"""
GMOs are created by ________ 

generating genomic DNA fragments with restriction endonucleases
introducing recombinant DNA into an organism by any means
overexpressing proteins in E. coli
all of the above



Insulin produced by molecular cloning: 

is of pig origin
is a recombinant protein
is made by the human pancreas
is recombinant DNA



The Flavr Savr Tomato: 

is a variety of vine-ripened tomato in the supermarket
was created to have better flavor and shelf-life
does not undergo soft rot
all of the above



Linkage analysis ________ 

is used to create a physical map
is based on the natural recombination process
requires radiation hybrid mapping
involves breaking and rejoining of DNA artificially



Individual genetic maps in a given species are: 

genetically similar
genetically identical
genetically dissimilar
not useful in species analysis



The chain termination method of sequencing: 

uses labeled ddNTPs
uses only dideoxynucleotides
uses only deoxynucleotides
uses labeled dNTPs



Sequencing an individual person’s genome 

is currently possible
could lead to legal issues regarding discrimination and privacy
could help make informed choices about medical treatment
all of the above



All of the above
Genomics can be used in agriculture to: 

generate new hybrid strains
improve disease resistance
improve yield
all of the above



All of the above. Genomics can be used in agriculture to create new hybrid strains with desirable traits, improve disease resistance in crops, and increase yield by identifying and improving key genetic factors.
What is a biomarker? 

the color coding of different genes
a protein that is uniquely produced in a diseased state
a molecule in the genome or proteome
a marker that is genetically inherited



A biomarker is a molecule in the genome or proteome that is indicative of a particular biological or pathological condition, such as a disease. It can include proteins, DNA, RNA, metabolites, and other molecules that are produced or present in different quantities in response to certain conditions or diseases. Biomarkers can be used for diagnostic purposes, monitoring disease progression, and assessing treatment responses.
Which scientific concept did Charles Darwin and Alfred Wallace independently discover? 

mutation
natural selection
overbreeding
sexual reproduction



Which description is an example of a phenotype? 

A certain duck has a blue beak
A mutation occurred to a flower
Most cheetahs live solitary lives
both a and c



Which situation would most likely lead to allopatric speciation? 

Flood causes the formation of a new lake
A storm causes several large trees to fall down
A mutation causes a new trait to develop
An injury



Flood causes the formation of a new lake.
Which variable increases the likelihood of allopatric speciation taking place more quickly? 

lower rate of mutation
longer distance between divided groups
increased instances of hybrid formation
equivalent numbers of individuals in each population



Which reproductive combination produces hybrids? 

when individuals of the same species in different geographical areas reproduce
when any two individuals sharing the same habitat reproduce
when members of closely related species reproduce
when offspring of the same parents reproduce



When members of closely related species reproduce.
Which situation is not an example of a prezygotic barrier? 

Two species of turtles breed at different times of the year
Two species of flowers attract different pollinators
Two species of birds display different mating dances
Two species of insects produce infertile offspring



Two species of insects producing infertile offspring.
Which components of speciation would be least likely to be a part of punctuated equilibrium? 

a division of populations
a change in environmental conditions
ongoing gene flow among all individuals
a large number of mutations taking place at once



ongoing gene flow among all individuals 

Punctuated equilibrium typically involves isolated populations undergoing rapid evolutionary changes without gene flow between them. If ongoing gene flow is taking place among all individuals, it is less likely to lead to the rapid divergence of isolated populations characteristic of punctuated equilibrium.
What is the difference between micro- and macroevolution? 

Microevolution describes the evolution of small organisms, such as insects, while macroevolution describes the evolution of large organisms, like people and elephants.
Microevolution describes the evolution of microscopic entities, such as molecules and proteins, while macroevolution describes the evolution of whole organisms.
Microevolution describes the evolution of organisms in populations, while macroevolution describes the evolution of species over long periods of time.
Microevolution describes the evolution of organisms over their lifetimes, while macroevolution describes the evolution of organisms over multiple generations.





In reality, the main difference between micro- and macroevolution lies in the scale and scope of the changes being observed. Microevolution involves small-scale changes and adaptations within a population, such as changes in gene frequencies or the development of new traits over a relatively short period of time. These changes occur within a species and do not result in the formation of new species.

On the other hand, macroevolution involves larger-scale changes that occur over longer periods of time, leading to the formation of new species, genera, families, and higher taxonomic groups. These changes result in the diversification and branching out of lineages, leading to the development of new species and the extinction of others. Macroevolution is responsible for the vast diversity of life forms on Earth and the patterns of evolutionary relationships between different groups of organisms.
Which of the following populations is not in Hardy-Weinberg equilibrium? 

a population with 12 homozygous recessive individuals (yy), 8 homozygous dominant individuals (YY), and 4 heterozygous individuals (Yy)
a population in which the allele frequencies do not change over time
p2 + 2pq + q2 = 1
a population undergoing natural selection



When male lions reach sexual maturity, they leave their group in search of a new pride. This can alter the allele frequencies of the population through which of the following mechanisms? 

natural selection
genetic drift
gene flow
random mating



What is assortative mating? 

when individuals mate with those who are similar to themselves
when individuals mate with those who are dissimilar to themselves
when individuals mate with those who are the most fit in the population
when individuals mate with those who are least fit in the population



Assortative mating is when individuals mate with those who are similar to themselves. This can occur based on a variety of factors such as physical appearance, behavior, intelligence, or socioeconomic status.
Score:9/20


[[0, 3, 1], [1, 1, 1], [1, 3, 3], [1, 1, 1], [1, 0, 0], [1, 0, 0], [0, -1, 3], [0, -1, 3], [0, -1, 1], [1, 1, 1], [0, 0, 3], [0, -1, 0], [1, 1, 1], [0, -1, 2], [0, -1, 3], [0, -1, 2], [0, -1, 2], [1, 3, 3], [1, 2, 2], [0, -1, 0]]
"""

# %% [markdown]
# ## Improve on prompt engieering. Play on ChatGPT
# After inputing the same prompt to ChatGPT 3.5, I am able to reproduce the same problem.
# I tried few prompts and this one works:
# ```
# You are a student doing multiple choice question. You are asked to output the correct choice index (0 to 3, inclusive). No other wording is allowed before or after the index.
#
# What is assortative mating?
#
# when individuals mate with those who are similar to themselves
# when individuals mate with those who are dissimilar to themselves
# when individuals mate with those who are the most fit in the population
# when individuals mate with those who are least fit in the population
# ```
# After incorporating the prompt to the hip_agent.py, the score jumps to 16+
#
# Below listed the questions that GPT didn't get right:

# %%
"""
Question: Individual genetic maps in a given species are:
Gpt chooses the wrong answer: 2, correct answer: 0
Question: The chain termination method of sequencing:
Gpt chooses the wrong answer: 1, correct answer: 0
Question: Which description is an example of a phenotype?
Gpt chooses the wrong answer: 0, correct answer: 3
Score:17/20


[[1, 1, 1], [1, 1, 1], [1, 3, 3], [1, 1, 1], [0, 2, 0], [0, 1, 0], [1, 3, 3], [1, 3, 3], [1, 1, 1], [1, 1, 1], [0, 0, 3], [1, 0, 0], [1, 1, 1], [1, 2, 2], [1, 3, 3], [1, 2, 2], [1, 2, 2], [1, 3, 3], [1, 2, 2], [1, 0, 0]]
"""
